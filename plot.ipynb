# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, HTML

# %%
# notebook: for interactive zoom, pan, resize, query data points
# inline: for diagram export, printing etc

# %matplotlib notebook

# %%
def load_csv(filename):
    "Read in csv from filename, related info, return dataframe"

    df = pd.read_csv(filename, low_memory=False) 
    print("Columns: %s" % str(' '.join(df.columns)))
    print("Descriptive statistics for numeric columns via describe():")
    display(df.describe())
    return df

# %%
df = load_csv("monitor.csv");
# Out:
# Columns: ts dsl1_rxbw dsl2_rxbw dsl1_txbw dsl2_txbw dsl1_lastrx dsl2_lastrx dsl1_lasttx dsl2_lasttx
# Descriptive statistics for numeric columns via describe():
#          dsl1_rxbw    dsl2_rxbw    dsl1_txbw    dsl2_txbw   dsl1_lastrx  \
# count  1860.000000  1860.000000  1860.000000  1860.000000  1.860000e+03
# mean      1.509887     1.507186     0.445619     0.446237  4.982119e+06
# std       2.633363     2.614559     0.734557     0.753038  9.022579e+03
# min      -0.068440    -0.068440    -0.074220    -0.074220  4.969365e+06
# 25%       0.000000     0.000000     0.000000     0.000000  4.973775e+06
# 50%       0.619335     0.623600     0.204000     0.202800  4.979903e+06
# 75%       1.914335     1.918900     0.488000     0.488000  4.991066e+06
# max      42.045600    42.045600    11.198670    13.438400  4.998050e+06
#
#         dsl2_lastrx    dsl1_lasttx    dsl2_lasttx
# count  1.860000e+03    1860.000000    1860.000000
# mean   4.982122e+06  607062.672535  607063.512487
# std    9.023143e+03    2873.024988    2873.145689
# min    4.969365e+06  603270.664000  603270.664000
# 25%    4.973775e+06  604693.444000  604693.444000
# 50%    4.979950e+06  605663.232000  605671.908000
# 75%    4.991066e+06  610305.050000  610305.050000
# max    4.998068e+06  611756.288000  611757.656000

# %%
# But since we actually want to parse some dates, we do this load by hand.
df = pd.read_csv("monitor.out", parse_dates=['ts'])

# %%
df.set_index('ts', inplace=True)

# %%
df
# Out:
#                             dsl1_rxbw  dsl2_rxbw  dsl1_txbw  dsl2_txbw  \
# ts
# 2020-08-27 10:20:20.174455     0.0000     0.0000     0.0000     0.0000
# 2020-08-27 10:20:30.384004     0.0000     0.0000     0.0000     0.0000
# 2020-08-27 10:20:40.629794     0.1744     0.1744     0.1688     0.1688
# 2020-08-27 10:20:50.870236     2.8184     2.8184     0.2528     0.2528
# 2020-08-27 10:21:01.030877     0.0000     0.0000     0.0000     0.0000
# ...                               ...        ...        ...        ...
# 2020-08-27 15:45:57.500596     3.5416     3.5416     0.1480     0.1480
# 2020-08-27 15:46:07.857096     0.0624     0.0624     0.0696     0.0696
# 2020-08-27 15:46:18.302853     0.0000     1.7880     0.0000     0.1368
# 2020-08-27 15:46:28.669418     1.7880     0.0000     0.1368     0.0000
# 2020-08-27 15:46:39.055666     7.4560     7.4560     0.2216     0.2216
#
#                             dsl1_lastrx  dsl2_lastrx  dsl1_lasttx  dsl2_lasttx
